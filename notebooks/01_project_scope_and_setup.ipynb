# %%
# Mengecek apakah Jupyter Notebook berjalan pada environment project yang benar

import sys
import platform

print("Python Version:")
print(sys.version)

print("\nPython Executable:")
print(sys.executable)

print("\nOperating System:")
print(platform.platform())
# Out:
# Python Version:
# 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]
#
# Python Executable:
# C:\ProgramData\anaconda3\envs\youtube-rupiah-sentiment\python.exe
#
# Operating System:
# Windows-10-10.0.19045-SP0

# %%
# Mengecek lokasi kerja notebook saat ini

import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# D:\DATA-KAMIL\MATKUL\SEMESTER-1\DATA MINING\youtube-rupiah-sentiment-analysis\notebooks

# %%
# Validasi library utama project

import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import sklearn
import nltk
import Sastrawi
import streamlit
import plotly
import joblib
import yaml
import tqdm
import emoji

print("Semua library utama berhasil diimpor.")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)
print("Streamlit:", streamlit.__version__)
# Out:
# Semua library utama berhasil diimpor.
# Pandas: 3.0.3
# NumPy: 2.4.6
# Scikit-learn: 1.8.0
# Matplotlib: 3.10.9
# Seaborn: 0.13.2
# Streamlit: 1.58.0

# %% [markdown]
# ## Setup Struktur Folder dan File Konfigurasi Awal
#
# Pada tahap ini, struktur folder project telah dibuat untuk mendukung alur kerja Data Mining secara bertahap, mulai dari penyimpanan data mentah, data sementara, data hasil preprocessing, data berlabel, model, output visualisasi, hingga aplikasi Streamlit.
#
# File konfigurasi awal juga telah disiapkan, meliputi `.env`, `.env.example`, `.gitignore`, `config.yaml`, `requirements.txt`, `environment.yml`, dan `README.md`.
#
# File `.env` digunakan untuk menyimpan API key secara lokal dan tidak akan dipublikasikan ke GitHub. Dataset raw, interim, processed, dan labeled juga dikecualikan dari GitHub untuk menjaga keamanan dan privasi data komentar YouTube. Dataset yang dapat dipublikasikan hanya dataset sample yang sudah dianonimkan.
